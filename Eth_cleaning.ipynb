# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('eth_data.csv')
data.head()
# Out:
#                                                                                                                                        https://www.CryptoDataDownload.com
# unix          date                symbol   open          high          low           close         Volume ETH      Volume USDT                                 tradecount
# 1630713600000 2021-09-04 00:00:00 ETH/USDT 3938.11000000 3947.70000000 3913.62000000 3946.59000000 6635.24210000   26081128.32748000                                28103
# 1630627200000 2021-09-03 00:00:00 ETH/USDT 3785.82000000 4027.88000000 3705.05000000 3938.11000000 655903.75739000 2557662974.33001620                            1678132
# 1630540800000 2021-09-02 00:00:00 ETH/USDT 3826.82000000 3836.80000000 3717.04000000 3785.82000000 525165.79960000 1981758437.08575600                            1402190
# ...

# %%
data.reset_index()
# Out:
#             level_0              level_1   level_2        level_3  \
# 0              unix                 date    symbol           open
# 1     1630713600000  2021-09-04 00:00:00  ETH/USDT  3938.11000000
# 2     1630627200000  2021-09-03 00:00:00  ETH/USDT  3785.82000000
# 3     1630540800000  2021-09-02 00:00:00  ETH/USDT  3826.82000000
# 4     1630454400000  2021-09-01 00:00:00  ETH/USDT  3429.19000000
# ...             ...                  ...       ...            ...
# 1477   1503273600.0           2017-08-21  ETH/USDT          299.1
# 1478   1503187200.0           2017-08-20  ETH/USDT         290.91
# 1479   1503100800.0           2017-08-19  ETH/USDT         293.96
# 1480   1503014400.0           2017-08-18  ETH/USDT            302
# 1481   1502928000.0           2017-08-17  ETH/USDT         303.61
#
#             level_4        level_5        level_6          level_7  \
# 0              high            low          close       Volume ETH
# ...

# %%
type(data)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1482 entries, ('unix', 'date', 'symbol', 'open', 'high', 'low', 'close', 'Volume ETH', 'Volume USDT') to ('1502928000.0', '2017-08-17', 'ETH/USDT', '303.61', '312.18', '298.21', '302', '6155.32', '1890017.53')
# Data columns (total 1 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   https://www.CryptoDataDownload.com  1358 non-null   object
# dtypes: object(1)
# memory usage: 418.7+ KB

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'level_0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-2d1919da15f6> in <module>
# ...
